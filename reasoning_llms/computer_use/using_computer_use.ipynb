# %%
from simple_computer_use import execute_gui_command, create_gui_automation_graph

# %%
# Create the automation graph
automation_graph = create_gui_automation_graph()

automation_graph

# %%
result = execute_gui_command(
    "click on the computer use file tab",
    model_name="anthropic/claude-opus-4", reasoning_effort="medium", 
    automation_graph=automation_graph
)
# Out:
# 🚀 Starting GUI automation for: 'click on  the computer use file tab'
# ...
# 📸 Taking high-quality screenshot for command: click on  the computer use file tab
# The image is 3024x1964
# 🧠 Analyzing screenshot and planning action for: click on  the computer use file tab
# Number of messages: 1
# ⚡ Executing GUI action...
# Executing click with args: {'x': 397, 'y': 88}
# ...
# ✅ Automation completed!
# Command: click on  the computer use file tab
#
# 🧠 AI Reasoning:
# Reasoning: The user wants me to click on the "computer use file tab". Looking at the screenshot, I can see there are multiple tabs open in what appears to be Visual Studio Code. I need to find the tab labeled "computer_use" or similar.
#
# Looking at the tab bar, I can see several tabs:
# - computer_use_reasoning.ipynb
# - simple_computer_use.py (marked with M)
# - using_computer_use.ipynb (has a filled dot indicating current active tab)
#
# ...
